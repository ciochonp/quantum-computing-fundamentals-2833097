# %%
from qiskit import *
from qiskit.tools.visualization import plot_histogram
# %matplotlib inline

# %%
circuit = QuantumCircuit(2)
circuit.h(0)
circuit.cx(0, 1)
circuit.measure_all()
circuit.draw(output='mpl')
# Out:
# /home/codespace/.local/lib/python3.10/site-packages/qiskit/visualization/circuit/matplotlib.py:266: FutureWarning: The default matplotlib drawer scheme will be changed to "iqp" in a following release. To silence this warning, specify the current default explicitly as style="clifford", or the new default as style="iqp".
#   self._style, def_font_ratio = load_style(self._style)

# %%
simulator = Aer.get_backend('qasm_simulator')
result = execute(circuit, backend=simulator).result()
plot_histogram(result.get_counts())

# %%
from qiskit_ibm_runtime import QiskitRuntimeService
from qiskit.tools.monitor import job_monitor
from qiskit import IBMQ
IBMQ.enable_account('52d7eb79423aac78dc4da2c8bd04a922e749abd3f52a95cd42801f415b91eda2e9aeedba47d066de50cf6ce63f1a17eac7777bb1da18a2a0889c9a22500097ba')
provider = IBMQ.load_account()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# File ~/.local/lib/python3.10/site-packages/qiskit/__init__.py:169, in IBMQWrapper.__getattr__(self, attr)
#     168 try:
# --> 169     from qiskit.providers import ibmq
#     171     self.ibmq = ibmq.IBMQ
#
# ImportError: cannot import name 'ibmq' from 'qiskit.providers' (/home/codespace/.local/lib/python3.10/site-packages/qiskit/providers/__init__.py)
#
# The above exception was the direct cause of the following exception:
#
# MissingOptionalLibraryError               Traceback (most recent call last)
# Cell In[9], line 4
#       2 from qiskit.tools.monitor import job_monitor
#       3 from qiskit import IBMQ
# ----> 4 IBMQ.enable_account('52d7eb79423aac78dc4da2c8bd04a922e749abd3f52a95cd42801f415b91eda2e9aeedba47d066de50cf6ce63f1a17eac7777bb1da18a2a0889c9a22500097ba')
#       5 provider = IBMQ.load_account()
#
# ...

# %%
qcomp = provider.get_backend('ibm_brisbane')
job = execute(circuit, backend=qcomp)
job_monitor(job)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 qcomp = provider.get_backend('ibm_brisbane')
#       2 job = execute(circuit, backend=qcomp)
#       3 job_monitor(job)
#
# NameError: name 'provider' is not defined

# %%
qcomp_result = job.result()
plot_histogram(qcomp_result.get_counts())
