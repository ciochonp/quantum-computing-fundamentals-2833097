# %%
from qiskit import *
# %matplotlib inline

# %%
circuit = QuantumCircuit(4, 2)
circuit.x(0) # initalize input A
circuit.x(1) # initalize input B
circuit.barrier()

#circuit.cnot(1,2)
circuit.toffoli(0,1,2)
circuit.cnot(0,2)

circuit.barrier()
circuit.measure(2, 0) # measure SUM
circuit.measure(3, 1) # measure CARRY-OUT
circuit.draw(output='mpl')
# Out:
# /tmp/ipykernel_7210/4037858755.py:7: DeprecationWarning: The method ``qiskit.circuit.quantumcircuit.QuantumCircuit.toffoli()`` is deprecated as of qiskit 0.45.0. It will be removed no earlier than 3 months after the release date. Use QuantumCircuit.ccx as direct replacement.
#   circuit.toffoli(0,1,2)
# /tmp/ipykernel_7210/4037858755.py:8: DeprecationWarning: The method ``qiskit.circuit.quantumcircuit.QuantumCircuit.cnot()`` is deprecated as of qiskit 0.45.0. It will be removed no earlier than 3 months after the release date. Use QuantumCircuit.cx as direct replacement.
#   circuit.cnot(0,2)

# %%
# simulate circuit and print message with SUM and CARRY-OUT states
simulator = Aer.get_backend('qasm_simulator')
result = execute(circuit, backend=simulator, shots=1).result()
counts = result.get_counts()
print(f'SUM is {list(counts.keys())[0][1]}')
print(f'CARRY-OUT is {list(counts.keys())[0][0]}')
# Out:
# SUM is 0
# CARRY-OUT is 0
